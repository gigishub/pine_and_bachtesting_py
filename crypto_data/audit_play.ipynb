# %%
import sys 
from pathlib import Path
repo_root = Path.cwd().parent
sys.path.insert(0, str(repo_root))
from crypto_data.audit import audit_all


scores = audit_all(
    symbols=["ETHUSDT","SOLUSDT"],
    timeframes=["1d","4h", "1h", "15m"],
)
